# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import KFold
import joblib

# %%
df_train = pd.read_csv('raw182_Training_Relabeled_Auto_25.csv')
df_test = pd.read_csv('raw91_Testing_Relabeled_Auto_25.csv')
df_adl = pd.read_csv('Raw_Data_90ADL.csv')

# %%
print("Training Data Columns:", df_train.columns)
print("Testing Data Columns:", df_test.columns)
print("ADL Data Columns:", df_adl.columns)
# Out:
# Training Data Columns: Index([' ms_accelerometer_x', ' ms_accelerometer_y', ' ms_accelerometer_z',
#        'outcome'],
#       dtype='object')
# Testing Data Columns: Index([' ms_accelerometer_x', ' ms_accelerometer_y', ' ms_accelerometer_z',
#        'outcome'],
#       dtype='object')
# ADL Data Columns: Index([' ms_accelerometer_x', ' ms_accelerometer_y', ' ms_accelerometer_z',
#        'outcome'],
#       dtype='object')

# %%
# Clean column names by removing leading and trailing spaces
df_train.columns = df_train.columns.str.strip()
df_test.columns = df_test.columns.str.strip()
df_adl.columns = df_adl.columns.str.strip()

# Print cleaned column names
print("Training Data Columns:", df_train.columns)
print("Testing Data Columns:", df_test.columns)
print("ADL Data Columns:", df_adl.columns)

# Prepare the training and testing data
X_train = df_train[['ms_accelerometer_x', 'ms_accelerometer_y', 'ms_accelerometer_z']].values
y_train = df_train['outcome'].values

X_test = df_test[['ms_accelerometer_x', 'ms_accelerometer_y', 'ms_accelerometer_z']].values
y_test = df_test['outcome'].values

X_adl = df_adl[['ms_accelerometer_x', 'ms_accelerometer_y', 'ms_accelerometer_z']].values
y_adl = df_adl['outcome'].values
# Out:
# Training Data Columns: Index(['ms_accelerometer_x', 'ms_accelerometer_y', 'ms_accelerometer_z',
#        'outcome'],
#       dtype='object')
# Testing Data Columns: Index(['ms_accelerometer_x', 'ms_accelerometer_y', 'ms_accelerometer_z',
#        'outcome'],
#       dtype='object')
# ADL Data Columns: Index(['ms_accelerometer_x', 'ms_accelerometer_y', 'ms_accelerometer_z',
#        'outcome'],
#       dtype='object')

# %%
# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_adl_scaled = scaler.transform(X_adl)

# Add a dimension to the data for LSTM input: (samples, timesteps, features)
X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))
X_adl_scaled = X_adl_scaled.reshape((X_adl_scaled.shape[0], 1, X_adl_scaled.shape[1]))

# %%
# Define the class labels
class_labels = [0, 1]  # Update this based on your labels

# Convert labels to categorical format
label_encoder = LabelEncoder()
label_encoder.fit(class_labels)  # Fit on known labels

encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
encoded_y_adl = label_encoder.transform(y_adl)

one_hot_y_train = to_categorical(encoded_y_train)
one_hot_y_test = to_categorical(encoded_y_test)
one_hot_y_adl = to_categorical(encoded_y_adl)

# %%
def create_model():
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(50))
    model.add(Dropout(0.2))
    model.add(Dense(len(class_labels), activation='softmax'))  # Number of classes
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# K-Fold Cross-Validation
k_folds = 5
k_fold = KFold(n_splits=k_folds, shuffle=True, random_state=42)
scores = []

# %%
for train_indices, test_indices in k_fold.split(X_train_scaled):
    X_train_cv, X_test_cv = X_train_scaled[train_indices], X_train_scaled[test_indices]
    y_train_cv, y_test_cv = one_hot_y_train[train_indices], one_hot_y_train[test_indices]

    model = create_model()  # Reinitialize model for each fold

    # Train the model on the current fold
    history = model.fit(X_train_cv, y_train_cv, epochs=20, batch_size=16, validation_split=0.2, verbose=1)

    # Evaluate the model on the test data of the current fold
    _, accuracy = model.evaluate(X_test_cv, y_test_cv)
    scores.append(accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8664 - loss: 0.4186 - val_accuracy: 0.8696 - val_loss: 0.3738
# Epoch 2/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8791 - loss: 0.3412 - val_accuracy: 0.8699 - val_loss: 0.3723
# Epoch 3/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8746 - loss: 0.3480 - val_accuracy: 0.8705 - val_loss: 0.3720
# Epoch 4/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8769 - loss: 0.3399 - val_accuracy: 0.8677 - val_loss: 0.3689
# Epoch 5/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8686 - loss: 0.3527 - val_accuracy: 0.8731 - val_loss: 0.3580
# Epoch 6/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8730 - loss: 0.3500 - val_accuracy: 0.8707 - val_loss: 0.3605
# Epoch 7/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8743 - loss: 0.3377 - val_accuracy: 0.8738 - val_loss: 0.3501
# Epoch 8/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8757 - loss: 0.3346 - val_accuracy: 0.8751 - val_loss: 0.3419
# Epoch 9/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8803 - loss: 0.3252 - val_accuracy: 0.8736 - val_loss: 0.3424
# Epoch 10/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8767 - loss: 0.3318 - val_accuracy: 0.8725 - val_loss: 0.3348
# Epoch 11/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8800 - loss: 0.3252 - val_accuracy: 0.8731 - val_loss: 0.3275
# Epoch 12/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8803 - loss: 0.3259 - val_accuracy: 0.8762 - val_loss: 0.3242
# Epoch 13/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8769 - loss: 0.3284 - val_accuracy: 0.8773 - val_loss: 0.3256
# Epoch 14/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8780 - loss: 0.3259 - val_accuracy: 0.8786 - val_loss: 0.3200
# Epoch 15/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8809 - loss: 0.3213 - val_accuracy: 0.8764 - val_loss: 0.3190
# Epoch 16/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8802 - loss: 0.3240 - val_accuracy: 0.8788 - val_loss: 0.3207
# Epoch 17/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8798 - loss: 0.3198 - val_accuracy: 0.8767 - val_loss: 0.3163
# Epoch 18/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8794 - loss: 0.3214 - val_accuracy: 0.8758 - val_loss: 0.3157
# Epoch 19/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8804 - loss: 0.3193 - val_accuracy: 0.8762 - val_loss: 0.3148
# Epoch 20/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8824 - loss: 0.3146 - val_accuracy: 0.8775 - val_loss: 0.3131
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8792 - loss: 0.3063
# Epoch 1/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8659 - loss: 0.4181 - val_accuracy: 0.8789 - val_loss: 0.3562
# Epoch 2/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8774 - loss: 0.3458 - val_accuracy: 0.8799 - val_loss: 0.3526
# Epoch 3/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8771 - loss: 0.3448 - val_accuracy: 0.8813 - val_loss: 0.3534
# Epoch 4/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8773 - loss: 0.3439 - val_accuracy: 0.8801 - val_loss: 0.3511
# Epoch 5/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8745 - loss: 0.3434 - val_accuracy: 0.8817 - val_loss: 0.3424
# Epoch 6/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8759 - loss: 0.3390 - val_accuracy: 0.8830 - val_loss: 0.3398
# Epoch 7/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8753 - loss: 0.3415 - val_accuracy: 0.8834 - val_loss: 0.3364
# Epoch 8/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8769 - loss: 0.3316 - val_accuracy: 0.8823 - val_loss: 0.3286
# Epoch 9/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8770 - loss: 0.3303 - val_accuracy: 0.8834 - val_loss: 0.3223
# Epoch 10/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8795 - loss: 0.3249 - val_accuracy: 0.8823 - val_loss: 0.3165
# Epoch 11/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8760 - loss: 0.3323 - val_accuracy: 0.8821 - val_loss: 0.3123
# Epoch 12/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8771 - loss: 0.3283 - val_accuracy: 0.8839 - val_loss: 0.3065
# Epoch 13/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8789 - loss: 0.3253 - val_accuracy: 0.8872 - val_loss: 0.3115
# Epoch 14/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8750 - loss: 0.3266 - val_accuracy: 0.8845 - val_loss: 0.3038
# Epoch 15/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8755 - loss: 0.3263 - val_accuracy: 0.8839 - val_loss: 0.3025
# Epoch 16/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8809 - loss: 0.3190 - val_accuracy: 0.8843 - val_loss: 0.2998
# Epoch 17/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8775 - loss: 0.3242 - val_accuracy: 0.8850 - val_loss: 0.2969
# Epoch 18/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8749 - loss: 0.3229 - val_accuracy: 0.8848 - val_loss: 0.2912
# Epoch 19/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8780 - loss: 0.3212 - val_accuracy: 0.8850 - val_loss: 0.2941
# Epoch 20/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8822 - loss: 0.3227 - val_accuracy: 0.8863 - val_loss: 0.2953
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8868 - loss: 0.2984
# Epoch 1/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8676 - loss: 0.4236 - val_accuracy: 0.8727 - val_loss: 0.3672
# Epoch 2/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8733 - loss: 0.3475 - val_accuracy: 0.8712 - val_loss: 0.3606
# Epoch 3/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8756 - loss: 0.3417 - val_accuracy: 0.8727 - val_loss: 0.3621
# Epoch 4/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8740 - loss: 0.3454 - val_accuracy: 0.8720 - val_loss: 0.3563
# Epoch 5/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8783 - loss: 0.3343 - val_accuracy: 0.8729 - val_loss: 0.3534
# Epoch 6/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8785 - loss: 0.3294 - val_accuracy: 0.8738 - val_loss: 0.3451
# Epoch 7/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8767 - loss: 0.3323 - val_accuracy: 0.8738 - val_loss: 0.3434
# Epoch 8/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8750 - loss: 0.3341 - val_accuracy: 0.8755 - val_loss: 0.3333
# Epoch 9/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8767 - loss: 0.3299 - val_accuracy: 0.8758 - val_loss: 0.3284
# Epoch 10/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8793 - loss: 0.3289 - val_accuracy: 0.8769 - val_loss: 0.3277
# Epoch 11/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8760 - loss: 0.3287 - val_accuracy: 0.8780 - val_loss: 0.3195
# Epoch 12/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8821 - loss: 0.3184 - val_accuracy: 0.8799 - val_loss: 0.3153
# Epoch 13/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8788 - loss: 0.3245 - val_accuracy: 0.8791 - val_loss: 0.3176
# Epoch 14/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8788 - loss: 0.3216 - val_accuracy: 0.8797 - val_loss: 0.3105
# Epoch 15/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8794 - loss: 0.3219 - val_accuracy: 0.8808 - val_loss: 0.3087
# Epoch 16/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8808 - loss: 0.3199 - val_accuracy: 0.8797 - val_loss: 0.3052
# Epoch 17/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8823 - loss: 0.3125 - val_accuracy: 0.8793 - val_loss: 0.3079
# Epoch 18/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8800 - loss: 0.3166 - val_accuracy: 0.8854 - val_loss: 0.3001
# Epoch 19/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8805 - loss: 0.3194 - val_accuracy: 0.8835 - val_loss: 0.3079
# Epoch 20/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8807 - loss: 0.3164 - val_accuracy: 0.8797 - val_loss: 0.3037
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8727 - loss: 0.3392
# Epoch 1/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8669 - loss: 0.4255 - val_accuracy: 0.8711 - val_loss: 0.3686
# Epoch 2/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8700 - loss: 0.3555 - val_accuracy: 0.8711 - val_loss: 0.3685
# Epoch 3/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8719 - loss: 0.3527 - val_accuracy: 0.8738 - val_loss: 0.3633
# Epoch 4/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8740 - loss: 0.3422 - val_accuracy: 0.8764 - val_loss: 0.3508
# Epoch 5/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8731 - loss: 0.3438 - val_accuracy: 0.8745 - val_loss: 0.3570
# Epoch 6/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8748 - loss: 0.3424 - val_accuracy: 0.8727 - val_loss: 0.3526
# Epoch 7/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8736 - loss: 0.3409 - val_accuracy: 0.8771 - val_loss: 0.3435
# Epoch 8/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8788 - loss: 0.3283 - val_accuracy: 0.8729 - val_loss: 0.3445
# Epoch 9/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8782 - loss: 0.3321 - val_accuracy: 0.8788 - val_loss: 0.3273
# Epoch 10/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8781 - loss: 0.3265 - val_accuracy: 0.8797 - val_loss: 0.3211
# Epoch 11/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8767 - loss: 0.3292 - val_accuracy: 0.8802 - val_loss: 0.3245
# Epoch 12/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8799 - loss: 0.3206 - val_accuracy: 0.8817 - val_loss: 0.3100
# Epoch 13/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8766 - loss: 0.3260 - val_accuracy: 0.8817 - val_loss: 0.3068
# Epoch 14/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8776 - loss: 0.3228 - val_accuracy: 0.8874 - val_loss: 0.3047
# Epoch 15/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8725 - loss: 0.3327 - val_accuracy: 0.8823 - val_loss: 0.3015
# Epoch 16/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8773 - loss: 0.3241 - val_accuracy: 0.8856 - val_loss: 0.3008
# Epoch 17/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8807 - loss: 0.3170 - val_accuracy: 0.8846 - val_loss: 0.2987
# Epoch 18/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8774 - loss: 0.3260 - val_accuracy: 0.8865 - val_loss: 0.2961
# Epoch 19/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8758 - loss: 0.3213 - val_accuracy: 0.8863 - val_loss: 0.2949
# Epoch 20/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8771 - loss: 0.3187 - val_accuracy: 0.8830 - val_loss: 0.3008
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8853 - loss: 0.3121
# Epoch 1/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8675 - loss: 0.4200 - val_accuracy: 0.8756 - val_loss: 0.3621
# Epoch 2/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8765 - loss: 0.3454 - val_accuracy: 0.8747 - val_loss: 0.3640
# Epoch 3/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8761 - loss: 0.3427 - val_accuracy: 0.8775 - val_loss: 0.3584
# Epoch 4/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8759 - loss: 0.3421 - val_accuracy: 0.8777 - val_loss: 0.3543
# Epoch 5/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8764 - loss: 0.3390 - val_accuracy: 0.8756 - val_loss: 0.3516
# Epoch 6/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8792 - loss: 0.3317 - val_accuracy: 0.8760 - val_loss: 0.3487
# Epoch 7/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8743 - loss: 0.3366 - val_accuracy: 0.8780 - val_loss: 0.3410
# Epoch 8/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8781 - loss: 0.3321 - val_accuracy: 0.8784 - val_loss: 0.3331
# Epoch 9/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8760 - loss: 0.3360 - val_accuracy: 0.8786 - val_loss: 0.3290
# Epoch 10/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8793 - loss: 0.3246 - val_accuracy: 0.8766 - val_loss: 0.3292
# Epoch 11/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8763 - loss: 0.3296 - val_accuracy: 0.8813 - val_loss: 0.3169
# Epoch 12/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8758 - loss: 0.3289 - val_accuracy: 0.8801 - val_loss: 0.3154
# Epoch 13/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8813 - loss: 0.3220 - val_accuracy: 0.8801 - val_loss: 0.3139
# Epoch 14/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8788 - loss: 0.3244 - val_accuracy: 0.8801 - val_loss: 0.3083
# Epoch 15/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8821 - loss: 0.3185 - val_accuracy: 0.8801 - val_loss: 0.3147
# Epoch 16/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8768 - loss: 0.3219 - val_accuracy: 0.8826 - val_loss: 0.3138
# Epoch 17/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8812 - loss: 0.3199 - val_accuracy: 0.8839 - val_loss: 0.3046
# Epoch 18/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8815 - loss: 0.3168 - val_accuracy: 0.8812 - val_loss: 0.3035
# Epoch 19/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8757 - loss: 0.3251 - val_accuracy: 0.8823 - val_loss: 0.3040
# Epoch 20/20
# 1361/1361 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8781 - loss: 0.3202 - val_accuracy: 0.8817 - val_loss: 0.3077
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8793 - loss: 0.3213

# %%
# Calculate and print the mean accuracy
mean_accuracy = np.mean(scores)
print(f"Mean accuracy across {k_folds}-fold cross-validation: {mean_accuracy * 100:.2f}%")

# Train and evaluate the model on the entire training set and test set
model = create_model()
model.fit(X_train_scaled, one_hot_y_train, epochs=20, batch_size=16, validation_split=0.2, verbose=1)

# Evaluate on test set
test_loss, test_accuracy = model.evaluate(X_test_scaled, one_hot_y_test)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Mean accuracy across 5-fold cross-validation: 88.06%
# Epoch 1/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8643 - loss: 0.4068 - val_accuracy: 0.8695 - val_loss: 0.3703
# Epoch 2/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8748 - loss: 0.3465 - val_accuracy: 0.8749 - val_loss: 0.3644
# Epoch 3/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8745 - loss: 0.3459 - val_accuracy: 0.8760 - val_loss: 0.3584
# Epoch 4/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8774 - loss: 0.3390 - val_accuracy: 0.8746 - val_loss: 0.3510
# Epoch 5/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8776 - loss: 0.3360 - val_accuracy: 0.8724 - val_loss: 0.3519
# Epoch 6/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8791 - loss: 0.3315 - val_accuracy: 0.8779 - val_loss: 0.3363
# Epoch 7/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8763 - loss: 0.3345 - val_accuracy: 0.8780 - val_loss: 0.3235
# Epoch 8/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8800 - loss: 0.3208 - val_accuracy: 0.8793 - val_loss: 0.3180
# Epoch 9/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8824 - loss: 0.3197 - val_accuracy: 0.8801 - val_loss: 0.3165
# Epoch 10/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8798 - loss: 0.3253 - val_accuracy: 0.8817 - val_loss: 0.3125
# Epoch 11/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8786 - loss: 0.3265 - val_accuracy: 0.8802 - val_loss: 0.3193
# Epoch 12/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8839 - loss: 0.3133 - val_accuracy: 0.8805 - val_loss: 0.3030
# Epoch 13/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8841 - loss: 0.3114 - val_accuracy: 0.8789 - val_loss: 0.3036
# Epoch 14/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8753 - loss: 0.3260 - val_accuracy: 0.8799 - val_loss: 0.3104
# Epoch 15/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8796 - loss: 0.3195 - val_accuracy: 0.8871 - val_loss: 0.3025
# Epoch 16/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8779 - loss: 0.3231 - val_accuracy: 0.8843 - val_loss: 0.3056
# Epoch 17/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8813 - loss: 0.3189 - val_accuracy: 0.8789 - val_loss: 0.3045
# Epoch 18/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8815 - loss: 0.3126 - val_accuracy: 0.8801 - val_loss: 0.3009
# Epoch 19/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8835 - loss: 0.3117 - val_accuracy: 0.8810 - val_loss: 0.3043
# Epoch 20/20
# 1701/1701 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8773 - loss: 0.3202 - val_accuracy: 0.8824 - val_loss: 0.3004
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8836 - loss: 0.2930
# Test accuracy: 88.68%

# %%
# Predict on ADL data
y_adl_pred = model.predict(X_adl_scaled)
y_adl_pred = np.argmax(y_adl_pred, axis=1)
y_adl_true = np.argmax(one_hot_y_adl, axis=1)

# Classification report for ADL data
from sklearn.metrics import classification_report, confusion_matrix

print("Classification Report for ADL Data:")
print(classification_report(y_adl_true, y_adl_pred, target_names=[str(label) for label in class_labels]))

print("Confusion Matrix for ADL Data:")
print(confusion_matrix(y_adl_true, y_adl_pred))
# Out:
# 1461/1461 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step
# Classification Report for ADL Data:
#               precision    recall  f1-score   support
#
#            0       0.66      0.77      0.71     29191
#            1       0.48      0.35      0.41     17561
#
#     accuracy                           0.61     46752
#    macro avg       0.57      0.56      0.56     46752
# weighted avg       0.60      0.61      0.60     46752
#
# Confusion Matrix for ADL Data:
# [[22494  6697]
#  [11343  6218]]
